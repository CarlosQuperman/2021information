# %% [markdown]
# ### 아이돌 앨범 데이터를 이용한 순차, 선택, 반복 알아보기
#
# - 지난 시간에 우리는 교생 선생님들의 친절하고 자세한 수업을 통하여 프로그래밍의 구조인 순차, 선택, 반복 구조에 대해 알아보았습니다.
# - 프로그래밍의 구조인 순차, 선택, 반복이란 프로그램을 만들기 위해서 활용하는 구조로 우리 삶의 구조와 동일합니다.
# - 우리는 시간의 흐름에 따라 살아가고 (순차), 수 많은 갈림길(저녁 뭐 먹을까, 선택과목 뭐 들을까, 내 최애는 누구일까), 반복합니다(1교시부터 7교시까지, 졸업할 때 까지, 죽을 때 까지)
# - 프로그래밍의 구조가 순차, 선택, 반복인 이유는 우리 삶이 순차, 선택, 반복으로 이루어져있고 프로그램을 통해 우리 삶의 문제를 해결하기 위해서입니다.

# %% [markdown]
# ### 그래서 이번에는 순차, 선택, 반복 구조를 이용하여 4세대 아이돌 앨범 관련 정보 중 내가 알고 싶어하는 내용만 뽑아내는 프로그래밍을 진행해보겠습니다.
#
# * 자료 출처 : https://www.kaggle.com/daffashiddiq/kpop-4th-gen-sales
# * Kpop 4th gen Sales
# * Kpop 4세대 아이돌의 2017년부터 지금까지 엘범, 국가, 판매량, 최고 순위 등을 가지고 있는 데이터
# * 4세대 아이돌이 어떤 기준인지는 나도 모름!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 원격수업이기에 파일을 직접 업로드 하지는 않고 결과를 리스트에 저장해둠
# 리스트란? 관련 있는 데이터들을 이름 하나로 관리하기 위한 파이선의 자료구조(자료를 저장하는 구조)
# 강원사대부고 = [1학년, 2학년, 3학년] <- 강원사대부고라는 리스트 안에 1학년, 2학년, 3학년이 저장됨

header = ['Artist', 'title', 'date', 'country', 'sales', 'peak_chart']
data = [['IZONE', 'Bloom*iz', '2/17/2020', 'KOR', '492504', '2'] ,['IZONE', 'Bloom*iz', '2/17/2020', 'JPN', '23960', '3'] ,['IZONE', 'TWELVE', '10/21/2020', 'JPN', '135113', '1'] ,['IZONE', 'Color*Iz', '10/29/2018', 'KOR', '282816', '2'] ,['IZONE', 'Color*Iz', '10/29/2018', 'JPN', '48,734', '1'] ,['IZONE', 'Heart*Iz', '4/1/2020', 'KOR', '306812', '1'] ,['IZONE', 'Heart*Iz', '4/1/2020', 'JPN', '40065', '4'] ,['IZONE', 'Oneiric Diary', '6/15/2020', 'KOR', '559138', '2'] ,['IZONE', 'Oneiric Diary', '6/15/2020', 'JPN', '19928', '8'] ,['IZONE', 'One-reeler/Act IV', '12/7/2020', 'KOR', '447749', '1'] ,['ITZY', "It'z Icy", '5/29/2019', 'KOR', '149349', '3'] ,['ITZY', "It'z Icy", '5/29/2019', 'JPN', '15742', '12'] ,['ITZY', "It'z Me", '3/9/2020', 'KOR', '150851', '1'] ,['ITZY', "It'z Me", '3/9/2020', 'JPN', '10882', '13'] ,['ITZY', 'Not Shy', '8/17/2020', 'KOR', '219048', '1'] ,['ITZY', 'Not Shy', '8/17/2020', 'JPN', '14201', '8'] ,['Stray Kids', 'In Life', '9/14/2020', 'KOR', '473616', '1'] ,['Stray Kids', 'In Life', '9/14/2020', 'JPN', '39911', '11'] ,['Stray Kids', 'Mixtape', '1/8/2018', 'KOR', '118921', '2'] ,['Stray Kids', 'Mixtape', '1/8/2018', 'JPN', '1063', '47'] ,['Stray Kids', 'I Am Not', '3/26/2018', 'KOR', '159343', '4'] ,['Stray Kids', 'I Am Not', '3/26/2018', 'JPN', '2036', '0'] ,['Stray Kids', 'I Am Who', '8/6/2018', 'KOR', '185273', '3'] ,['Stray Kids', 'I Am Who', '8/6/2018', 'JPN', '1474', '34'] ,['Stray Kids', 'I Am You', '10/22/2018', 'KOR', '189129', '2'] ,['Stray Kids', 'I Am You', '10/22/2018', 'JPN', '2234', '34'] ,['Stray Kids', 'Miroh', '3/25/2019', 'KOR', '226383', '1'] ,['Stray Kids', 'Miroh', '3/25/2019', 'JPN', '5856', '15'] ,['Stray Kids', 'Yellow Wood', '6/19/2019', 'KOR', '192796', '2'] ,['Stray Kids', 'Yellow Wood', '6/19/2019', 'JPN', '3379', '17'] ,['Stray Kids', 'Levanter', '12/9/2019', 'KOR', '247074', '1'] ,['Stray Kids', 'Levanter', '12/9/2019', 'JPN', '9116', '17'] ,['Stray Kids', 'All In', '11/4/2020', 'JPN', '59361', '2'] ,['Treasure', 'Treasure Effect', '1/11/2021', 'KOR', '307457', '1'] ,['Treasure', 'Treasure Effect', '1/11/2021', 'JPN', '83755', '1'] ,['Treasure', 'Chapter One', '8/7/2020', 'KOR', '250000', '1'] ,['Treasure', 'Chapter Two', '9/18/2020', 'KOR', '239326', '2'] ,['Treasure', 'Chapter Three', '11/6/2020', 'KOR', '232134', '1'] ,['TXT', 'Magic', '10/21/2019', 'KOR', '300910', '1'] ,['TXT', 'Magic', '10/21/2019', 'JPN', '14296', '11'] ,['TXT', 'Still Dreaming', '1/20/2021', 'JPN', '102041', '1'] ,['TXT', 'Star', '3/4/2019', 'KOR', '278846', '1'] ,['TXT', 'Star', '3/4/2019', 'JPN', '26176', '3'] ,['TXT', 'Eternity', '5/18/2020', 'KOR', '379053', '2'] ,['TXT', 'Eternity', '5/18/2020', 'JPN', '38814', '1'] ,['TXT', 'Blue Hour', '10/26/2020', 'KOR', '508626', '1'] ,['TXT', 'Blue Hour', '10/26/2020', 'JPN', '43870', '1'] ,['(G)I-dle', 'Dumdi Dumdi', '8/3/2020', 'KOR', '125801', '2'] ,['(G)I-dle', 'Dumdi Dumdi', '8/3/2020', 'CHN', '182749', '0'] ,['(G)I-dle', 'I Am', '5/2/2018', 'KOR', '51831', '6'] ,['(G)I-dle', 'I Made', '2/26/2019', 'KOR', '51041', '2'] ,['(G)I-dle', 'I Trust', '4/6/2020', 'KOR', '154499', '1'] ,['(G)I-dle', 'I Trust', '4/6/2020', 'JPN', '1380', '48'] ,['(G)I-dle', 'I Burn', '1/11/2021', 'KOR', '207927', '3'] ,['(G)I-dle', 'Latata', '7/29/2019', 'JPN', '8229', '5'] ,['(G)I-dle', 'Oh My God', '8/26/2020', 'JPN', '4229', '23'] ,['Cravity', 'Season 1. Hideout: Remember Who We Are', '4/14/2020', 'KOR', '154360', '1'] ,['Cravity', 'Season 1. Hideout: Remember Who We Are', '4/14/2020', 'JPN', '7304', '10'] ,['Cravity', 'Season 2. Hideout: The New Day We Step Into\t\n', '4/24/2020', 'KOR', '166644', '1'] ,['Cravity', 'Season 2. Hideout: The New Day We Step Into\t\n', '4/24/2020', 'JPN', '10966', '15'] ,['Cravity', 'Season 2. Hideout: The New Day We Step Into\t\n', '1/19/2021', 'KOR', '162136', '3'] ,['Cravity', 'Season 2. Hideout: The New Day We Step Into\t\n', '1/19/2021', 'JPN', '8869', '12'] ,['Verivery', 'Veri-Us\t\n', '1/9/2019', 'KOR', '24080', '4'] ,['Verivery', 'Veri-Able', '4/24/2019', 'KOR', '17630', '6'] ,['Verivery', 'Face Me', '1/7/2020', 'KOR', '28440', '4'] ,['Verivery', 'Face You', '7/1/2020', 'KOR', '39626', '8'] ,['Verivery', 'Face Us', '10/13/2020', 'KOR', '59704', '7'] ,['Verivery', 'Veri-Chill', '7/31/2019', 'KOR', '16698', '10'] ,['Verivery', "Series 'O' Round 1: Hall", '3/2/2021', 'KOR', '49999', '4'] ,['Loona', '[ + +]', '8/20/2018', 'KOR', '61466', '2'] ,['Loona', '[#]', '2/5/2020', 'KOR', '83522', '2'] ,['Loona', '[12:00]', '10/19/2020', 'KOR', '116614', '4'] ,['Loona', 'Love & Live', '3/13/2017', 'KOR', '7130', '10'] ,['Loona', 'Mix & Match', '9/21/2017', 'KOR', '7869', '16'] ,['Loona', 'beauty&thebeat', '5/30/2018', 'KOR', '18138', '4'] ,['Loona', '[x x]', '2/19/2019', 'KOR', '45782', '3'] ,['Loona', 'Love & Evil', '4/27/2017', 'KOR', '5924', '24'] ,['Loona', 'Max & Match ', '10/31/2017', 'KOR', '11136', '7'] ,['Ateez', 'Treasure EP.Fin: All to Action', '10/8/2019', 'KOR', '209316', '1'] ,['Ateez', 'Treasure EP.Extra: Shift the Map', '12/4/2019', 'JPN', '13113', '9'] ,['Ateez', 'Into the A to Z', '3/24/2021', 'JPN', '10813', '6'] ,['Ateez', 'Treasure EP.1: All to Zero', '10/24/2018', 'KOR', '85109', '7'] ,['Ateez', 'Treasure EP.2: Zero to One', '1/15/2019', 'KOR', '100039', '6'] ,['Ateez', 'Treasure EP.3: One to All', '6/10/2019', 'KOR', '180121', '2'] ,['Ateez', 'Treasure EP.3: One to All', '6/10/2019', 'JPN', '2896', '25'] ,['Ateez', 'Treasure Epilogue: Action to Answer', '1/6/2020', 'KOR', '184339', '1'] ,['Ateez', 'Treasure Epilogue: Action to Answer', '1/6/2020', 'JPN', '1472', '31'] ,['Ateez', 'Treasure EP. Map to Answer', '2/12/2020', 'JPN', '18720', '3'] ,['Ateez', 'Zero: Fever Part.1', '7/29/2020', 'KOR', '379505', '1'] ,['Ateez', 'Zero: Fever Part.1', '7/29/2020', 'JPN', '11324', '35'] ,['Ateez', 'Zero: Fever Part.2', '3/1/2021', 'KOR', '380711', '1'] ,['Ateez', 'Zero: Fever Part.2', '3/1/2021', 'JPN', '11027', '10'] ,['Everglow', 'Reminiscence', '2/3/2020', 'KOR', '30912', '4'] ,['Everglow', 'Reminiscence', '2/3/2020', 'JPN', '1649', '48'] ,['Everglow', '-77.82X-78.29', '9/21/2020', 'KOR', '49388', '4'] ,['Everglow', 'Arrival of Everglow', '3/18/2019', 'KOR', '28033', '6'] ,['Everglow', 'Hush', '8/19/2019', 'KOR', '28639', '5'] ,]


print(header)
for row in data:
  #row라는 이름으로 data를 ()부터 ()까지 돈다. (포트폴리오 !!!) -> 빈칸 채울 것
  #(포트폴리오 !!!) 돌면서 한줄씩 출력하기 위한 내용을 이 문제 바로 아래칸에 입력하세요
  
#이것이 바로 순차 구조다! (처음부터 끝까지 돌면서 출력한다)

# %%
# 이 데이터에 있는 4세대 아이돌 그룹의 이름을 딱 '1번'만 선택해서 리스트에 저장하려고 한다.
# 저장하기 위해서는 어떻게 해야 할까?
# 한줄씩 돌면서 만나는 이름이 리스트에 없으면 추가하고
# 리스트에 있으면 무시한다.

idoln = [] #아이돌 이름을 저장하기 위한 리스트를 idoln으로 만듬

for row in data: 
  if row[] not in idoln: #(포트폴리오!!) 왼쪽에 있는 []안에 아이돌 이름이 있는 칸 순서를 컴퓨터 기준으로 적기 
    idoln.append(row[]) #(포트폴리오!!) 아이돌 이름이 있는 칸 내용을 idoln에 추가해주기 

print(idoln)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 위에서 뽑아낸 아이돌 이름을 바탕으로 
# 내가 키보드로 아이돌 이름을 입력하면 그 아이돌 관련 데이터(줄)만 선택해 출력하는 프로그램을 만들어 보자

idolname = () #(포트폴리오!!) 파이썬에서 키보드로 입력을 받기 위한 "함수"의 이름을 ()앞에 적으세요
print("내가 입력한 아이돌 이름은",idolname,"입니다!")

for row in data:
  if idolname in row[0]: #위에서 키보드로 입력받은 idolname이 row[0]에 있으면! 
    print(row)

# %% [markdown]
# * 위에서는 이름을 입력하면 그 그룹에 해당하는 정보를 출력해주었습니다.
# * 그런데 이름 말고 다른 값들을 기준으로 내가 원하는 값을 선택하여 출력할 수 있을까요?
# * header = ['Artist', 'title', 'date', 'country', 'sales', 'peak_chart']
# * 위 순서대로 되어 있는 데이터의 이름처럼
# * row[0]이 Artist를 담고 있기에 다른 데이터를 기준으로 데이터를 선택하고 싶다면 row[]안에 원하는 데이터의 위치를 기준으로 값을 '선택'하면 됩니다.

# %%
### 1등을 한 앨범 정보만 뽑아 출력해주기

for row in data:
  if row[-1]==1: #끝에서 첫번째가 제일 높은 차트 순위이므로 -1
    print(row)

# 실행 결과를 확인해보자
# 결과가 잘 나올까?

# %%
### row[-1]을 정수로 만든 다음 1이면 출력해주기

for row in data:
  if (row[-1])==1:  #(포트폴리오 !!) (row[-1])앞에 컴퓨터에서 정수(소수점이 없는 수를 의미하는 글자 처주기)
    print(row)

# %% [markdown]
# * 지금까지는 하나의 데이터 영역에서 값을 추출하는 것을 해보았습니다.
# * 이제는 두 가지 이상의 영역에서 데이터를 선택하여 추출하는 프로그래밍을 해보겠습니다.
# * 그룹명이 IZONE이고 발매일 중 연도가 2020년이고 한국에서 발매된 앨범을 출력하는 프로그래밍을 진행해보겠습니다.

# %%
for row in data:
  if row[0]=='IZONE' and int(row[2].split('')[])==2020 and row[3]=='KOR': #(포트폴리오!!) int(row[2].split('')[]) ''와 []에 들어갈 값을 입력해봅시다.
    print(row)

# %%
# (선택문제)
# 위 형식을 이용하여 내가 추출해보고 싶은 데이터를 골라 추출해보자

# %%
#(예) 발매연도가 2021년이고 최고 랭킹이 1위인 앨범들

# %%
#(예) ITZY의 앨범 중 2021년에 발매한 앨범들

# %%
#(예) 'Everglow'의 앨범 중 한국에서만 발매한 앨범들

# %% [markdown]
# * 지금까지 우리는 처음부터 끝까지 '반복'하며 특정한 조건을 만족하는 데이터를 '선택'하는 프로그래밍을 진행해보았습니다.
# * 이제 처음부터 끝까지 **'반복'**하면서 특정 조건을 처음부터 끝까지 **'반복'**하며 데이터를 '선택'하는 프로그래밍을 진행해보겠습니다.

# %%
# idoln에는 중복되지 않은 4세대 아이돌의 이름이 들어가 있음.
print(idoln)

# %% [markdown]
# - 1.모든 아이돌 앨범 데이터가 있는 data를 처음부터 끝까지 한줄씩 **반복**하는 과정에서
# - 2.idoln을 처음부터 끝까지 도는 것을 **반복**하면서 그 줄의 아이돌 이름과 일치하는 아이돌 이름을 찾아내고 예) row[0]의 값이 'ITZY'라면 idoln을 처음부터 돌면서 'ITZY'의 **위치**가 1번째(컴퓨터 기준)임을 찾아냄
# - 3.idollib(아이돌 라이브러리)라는 리스트를 만들고 그 안에 1번째 리스트에 row를 집어넣음

# %%
#idollib = [[IZONE],[ITZY]....]  순서대로 정보들을 담을 수 있는 idollib를 만들어서 각 리스트에 그룹별 데이터를 저장함
idollib = []
for i in range(): # (포트폴리오!!) 데이터에 있는 4세대 아이돌의 개수는? len은 length를 의미함
  idollib.append([])

print(idollib)

for row in data: #데이터를 처음부터 끝까지 돌면서
  for i in range(): # (포트폴리오!!) 아이돌 이름의 위치를 처음부터 끝까지 돔 ()안에는 아이돌 이름의 길이가 들어가게
    if row[0] == idoln[i]:
      idollib[i].append(row)
      #print(i)

#['IZONE', 'ITZY', 'Stray Kids', 'Treasure', 'TXT', '(G)I-dle', 'Cravity', 'Verivery', 'Loona', 'Ateez', 'Everglow']

print(idollib[]) #(포트폴리오!!) []안에 위에 있는 아이돌 이름 순서를 참고하여 컴퓨터가 이해하는 방식대로 내가 알고 싶은 아이돌의 위치를 적어줌

#for i in range(len(idollib[5)):
#  print(idollib[][i])

# %% [markdown]
# * **선택과제입니다!**
# * 자 이제 지금까지의 활동을 바탕으로 4세대 아이돌 데이터에서 내가 순차, 선택, 반복을 통해서 만들고 싶은 프로그램을 자유롭게 써봅시다.
# * 써본 내용을 바탕으로 직접 +코드를 눌러 구현해봐도 상관없습니다
# * 여기서 이야기하는 내용은 **선택**입니다

# %%
# 나는 이런 프로그램을 만들고 싶다
일본에서 1위한 앨범 정보만 추출하고 싶다
#<-를 쓰고 자유롭게 써볼 것

# %% [markdown]
# * **선택과제입니다.**
# * 전세계의 데이터 과학자, AI 개발자가 참여하는 곳인 Kaggle은 정말로 많은 데이터들이 있습니다.
# * 우리가 이전에 공공데이터 포털, 데이콘 등에서 관심 있는 데이터를 찾아 정리한 것처럼
# * 선생님이 4세대 아이돌 데이터를 Kaggle에서 찾아 수업 내용으로 만든 것처럼 Kaggle에서 관심 있는 데이터를 찾아보고
# * 찾은 데이터, 이 데이터를 선택한 이유, 이 데이터로 해보고 싶은 것을 자유롭게 적어봅시다.
# * Kaggle(https://www.kaggle.com/datasets)

# %%
내가 찾은 데이터 : 
내가 이 데이터를 선택한 이유 :
이 데이터로 해보고 싶은 것 :
