# %% [markdown]
# ### 교과서에 제시된 알고리즘을 이용하여 프로그래밍 언어를 이용하여 문제를 해결해보자

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
T = []# 최고, 최저온도를 구할 10개의 온도 
M =    # 최고온도
m =   # 최저온도 

# T같이 여러개의 값을 저장하는 공간을 리스트라고 하며 
# M, m같이 변하는 수를 저장하는 공간을 변수라고 하고 
# 1,2,3,4,"5"같이 정해진 값을 상수라고 한다 

print(T)

for t in T[:]: #t라는 이름으로 온도의 집합 T를 하나씩 이동함 [:] T를 돌면서 수정할 것임을 의미함.
  if t > M:
    M = t
  if t < m:
    m = t
  T.remove(t) # T가 공집합이 아니면 원소 삭제

print()
print()
print()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
door1 = [5,10,4,20] #원래의 수를 저장할 키의 값 (리스트)
door2 = [5,10,4,20] #더해가면서 답을 찾을 키의 값  (리스트)

count = 1

#  while은 ~~하는 동안에 반복하라는 뜻을 가지고 있음. ~~하는 동안? -> 우리가 구하는 답이 나오지 않는 동안? -> 답이 나오면? -> 종료
while door2[]!=door2[] or door2[]!=door2[] or door2[]!=door2[]:
  print("회수 : ", count)
  print("최소값 : ", min(door2))
  print("최소값이 있는 위치 :",door2.index(min(door2))) #index 위치 
  j = door2.index(min(door2))
  door2[j] = door2[j]+door1[j] 
  print(door2)
  count = count + 1
  print()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1부터 N까지 합을 구하는 알고리즘 1

S = 
i = 
count =    #더하기를 구하는 과정의 단계 저장

n = int(input("1부터 n까지의 합을 구할 때 n의 값을 입력하세요"))

while(i<=n): #목표 상태가 되지 않은 동안
  S = 
  count = count + 1
  i = 
  count+=1 #count+=1 은 count = count + 1과 같다

print(S)
print(count)
# Out:
# 1부터 n까지의 합을 구할 때 n의 값을 입력하세요10000000
# 50000005000000
# 20000000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1부터 N까지 합을 구하는 알고리즘 2

S = 
n = int(input("1부터 n까지의 합을 구할 때 n의 값을 입력하세요"))
S = n*()/

print(S)
#print("%.3f" %S)       #f float 실수를 의미함 
#print("%d" %S)         #d decimal 10진 정수를 의미함
# Out:
# 1부터 n까지의 합을 구할 때 n의 값을 입력하세요10000000
# 50000005000000.0
# 50000005000000.000
# 50000005000000
